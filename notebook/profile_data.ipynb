# %%
import pandas as pd
import datetime as dt
import pathlib as Path
import json

# %%
customers = pd.read_csv("C:/Users/abhis/OneDrive/Documents/abhishek/Data_Analyst_Abhishek/data_analyst/python_data/practice/Sales & Profitability Analytics/data/raw/customers.csv")

# %%
print(customers.shape)
print(customers.info())
print(customers.isna().sum())
print(customers.duplicated().sum())
# Out:
# (10000, 10)
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          10000 non-null  str
#  1   customer_name        10000 non-null  str
#  2   gender               10000 non-null  str
#  3   age                  10000 non-null  int64
#  4   city                 10000 non-null  str
#  5   state                9766 non-null   str
#  6   region_id            10000 non-null  str
#  7   customer_segment     10000 non-null  str
#  8   signup_date          10000 non-null  str
#  9   acquisition_channel  10000 non-null  str
# dtypes: int64(1), str(9)
# memory usage: 781.4 KB
# None
# customer_id              0
# customer_name            0
# gender                   0
# age                      0
# city                     0
# state                  234
# region_id                0
# customer_segment         0
# signup_date              0
# acquisition_channel      0
# dtype: int64
# 0

# %%
# checking customers
customers[customers['gender'].isnull() == True]
customers['gender'].isnull().value_counts()
# replace the null value with unknown
customers['gender'] = customers['gender'].fillna('Unknown')

# %%
 #checking acquisition_channel 
customers['acquisition_channel'].isna().value_counts()
customers[customers['acquisition_channel'].isna() == False]
# changing the null channel into unknown because to store it 
customers['acquisition_channel'] = customers['acquisition_channel'].fillna('Unknown')

# %%
# checking state
customers['state'].isna().value_counts()
customers[customers['state'].isna() == True]

customers[['city','state']].value_counts()
# Out:
# city           state
# Delhi          Delhi             981
# Kolkata        West Bengal       511
# Hyderabad      Telangana         502
# Bengaluru      Karnataka         454
# Mysuru         Karnataka         447
# Patna          Bihar             379
# Kochi          Kerala            377
# Faridabad      Haryana           370
# Gurugram       Haryana           369
# Mumbai         Maharashtra       335
# Pune           Maharashtra       324
# Nagpur         Maharashtra       322
# Surat          Gujarat           321
# Chennai        Tamil Nadu        318
# Coimbatore     Tamil Nadu        290
# Bhubaneswar    Odisha            286
# Ahmedabad      Gujarat           286
# Indore         Madhya Pradesh    247
# Bhopal         Madhya Pradesh    236
# Jodhpur        Rajasthan         229
# Ludhiana       Punjab            216
# Dehradun       Uttarakhand       211
# Raipur         Chhattisgarh      202
# Guwahati       Assam             200
# Ranchi         Jharkhand         194
# Amritsar       Punjab            187
# Noida          Uttar Pradesh     185
# Kanpur         Uttar Pradesh     185
# Jaipur         Rajasthan         168
# Visakhapatnam  Andhra Pradesh    151
# Lucknow        Uttar Pradesh     145
# Vijayawada     Andhra Pradesh    138
# Name: count, dtype: int64
